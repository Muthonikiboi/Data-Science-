# %%
info_table = [
    {"color": "green", "number": 7},
    {"color": "red", "number": 2},
    {"color": "orange", "number": 1}
]

type(info_table)
# Out:
# list

# %%
for row in info_table:
    print(row["color"])
# Out:
# green
# red
# orange

# %%
import pandas as pd
df = pd.DataFrame(info_table)
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
print(df["color"])
# Out:
# 0     green
# 1       red
# 2    orange
# Name: color, dtype: object

# %%
#Watch Videos on 1.Python Data Manipulation
#                2.List Comprehensions and Dictionary Comprehensions

# %% [markdown]
# # Input Output

# %%
x = [5, 6, 7]

# %%
hex(id(x))
# Out:
# '0x74772d4dd680'

# %%
x[0] = 10
x
# Out:
# [10, 6, 7]

# %%
output_file_obj = open("zen_of_python_cleaned.txt", mode="w")

# %%
# ls

# %% [markdown]
# # Working with CSV in Python

# %%
import csv

# %%
# with open("advertising.csv") as f:
#     # Pass the file in to a "reader" object and specify that
#     # values without explicit quotes (i.e. all values in this
#     # dataset) should be treated as numbers
#     reader = csv.reader(f, quoting=csv.QUOTE_NONNUMERIC)
#     # Get all of the data from the reader using `list`
#     track_times_with_csv_module = list(reader)
    
# track_times_with_csv_module

# %%
with open("results.csv") as f:
    reader = csv.reader(f)
    # Printing only the header and first 5 rows of data
    for _ in range(6):
        print(next(reader))
# Out:
# ['Gender', 'Event', 'Location', 'Year', 'Medal', 'Name', 'Nationality', 'Result']
# ['M', '10000M Men', 'Rio', '2016', 'G', 'Mohamed FARAH', 'USA', '25:05.17']
# ['M', '10000M Men', 'Rio', '2016', 'S', 'Paul Kipngetich TANUI', 'KEN', '27:05.64']
# ['M', '10000M Men', 'Rio', '2016', 'B', 'Tamirat TOLA', 'ETH', '27:06.26']
# ['M', '10000M Men', 'Beijing', '2008', 'G', 'Kenenisa BEKELE', 'ETH', '27:01.17']
# ['M', '10000M Men', 'Beijing', '2008', 'S', 'Sileshi SIHINE', 'ETH', '27:02.77']

# %%
with open("results.csv") as f:
    reader = csv.DictReader(f)
    results = list(reader)

# Print the first 5 rows of data
for index in range(5):
    print(results[index])
# Out:
# {'Gender': 'M', 'Event': '10000M Men', 'Location': 'Rio', 'Year': '2016', 'Medal': 'G', 'Name': 'Mohamed FARAH', 'Nationality': 'USA', 'Result': '25:05.17'}
# {'Gender': 'M', 'Event': '10000M Men', 'Location': 'Rio', 'Year': '2016', 'Medal': 'S', 'Name': 'Paul Kipngetich TANUI', 'Nationality': 'KEN', 'Result': '27:05.64'}
# {'Gender': 'M', 'Event': '10000M Men', 'Location': 'Rio', 'Year': '2016', 'Medal': 'B', 'Name': 'Tamirat TOLA', 'Nationality': 'ETH', 'Result': '27:06.26'}
# {'Gender': 'M', 'Event': '10000M Men', 'Location': 'Beijing', 'Year': '2008', 'Medal': 'G', 'Name': 'Kenenisa BEKELE', 'Nationality': 'ETH', 'Result': '27:01.17'}
# {'Gender': 'M', 'Event': '10000M Men', 'Location': 'Beijing', 'Year': '2008', 'Medal': 'S', 'Name': 'Sileshi SIHINE', 'Nationality': 'ETH', 'Result': '27:02.77'}

# %%
len(results)
# Out:
# 2394

# %%
import pandas as pd

# %%
from pandas import DataFrame

# %%
city = pd.read_excel('cities.xlsx')
# city.head()
city
# Out:
#                   City      Country  Population     Area
# 0                Solta      Croatia        1700       59
# 1           Greenville          USA       84554       68
# 2         Buenos Aires    Argentina    13591863     4758
# 3            Los Cabos       Mexico      287651     3750
# 4   Walla Walla Valley          USA       32237       33
# 5             Marakesh      Morocco      928850      200
# 6          Albuquerque   New Mexico      559277      491
# 7      Archipelago Sea      Finland       60000     8300
# 8         Iguazu Falls    Argentina           0      672
# 9        Salina Island        Italy        4000       27
# 10             Toronto       Canada         630  2731571
# 11         Pyeongchang  South Korea     2581000     3194

# %%
city.shape
# Out:
# (12, 4)

# %%
city.describe()
# Out:
#          Population          Area
# count  1.200000e+01  1.200000e+01
# mean   1.510980e+06  2.294269e+05
# std    3.876194e+06  7.879753e+05
# min    0.000000e+00  2.700000e+01
# 25%    3.425000e+03  6.575000e+01
# 50%    7.227700e+04  5.815000e+02
# 75%    6.516702e+05  4.002000e+03
# max    1.359186e+07  2.731571e+06

# %%
city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        12 non-null     object
#  1   Country     12 non-null     object
#  2   Population  12 non-null     int64
#  3   Area        12 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 512.0+ bytes

# %%
city['Population'].mean()
# Out:
# 1510980.1666666667

# %%
city['Population'].min()
# Out:
# 0

# %%
city['Population'].max()
# Out:
# 13591863

# %%
city['Population'].median()
# Out:
# 72277.0

# %%
len(city)
# Out:
# 12

# %%
import seaborn as sns

# %%
sns.histplot(y = city['Population'])
# Out:
# <AxesSubplot:xlabel='Count', ylabel='Population'>

# %%
sns.boxplot(x = city['Population'])
# Out:
# <AxesSubplot:xlabel='Population'>

# %%
results = pd.read_csv('results.csv', error_bad_lines= False)
results.head()
# Out:
# b'Skipping line 156: expected 8 fields, saw 9\nSkipping line 157: expected 8 fields, saw 9\nSkipping line 158: expected 8 fields, saw 9\nSkipping line 317: expected 8 fields, saw 9\nSkipping line 318: expected 8 fields, saw 9\nSkipping line 319: expected 8 fields, saw 9\nSkipping line 1658: expected 8 fields, saw 9\nSkipping line 1659: expected 8 fields, saw 9\nSkipping line 1660: expected 8 fields, saw 9\nSkipping line 1784: expected 8 fields, saw 9\nSkipping line 1785: expected 8 fields, saw 9\nSkipping line 1786: expected 8 fields, saw 9\n'
#   Gender       Event Location  Year Medal                   Name Nationality  \
# 0      M  10000M Men      Rio  2016     G          Mohamed FARAH         USA
# 1      M  10000M Men      Rio  2016     S  Paul Kipngetich TANUI         KEN
# 2      M  10000M Men      Rio  2016     B           Tamirat TOLA         ETH
# 3      M  10000M Men  Beijing  2008     G        Kenenisa BEKELE         ETH
# ...

# %%
results['Nationality'] == 'ETH'
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 2377    False
# 2378    False
# 2379    False
# 2380    False
# 2381    False
# Name: Nationality, Length: 2382, dtype: bool

# %%
results[results['Year'] == 2016]
# Out:
#      Gender              Event Location  Year Medal                   Name  \
# 0         M         10000M Men      Rio  2016     G          Mohamed FARAH
# 1         M         10000M Men      Rio  2016     S  Paul Kipngetich TANUI
# 2         M         10000M Men      Rio  2016     B           Tamirat TOLA
# 69        M           100M Men      Rio  2016     G             Usain BOLT
# 70        M           100M Men      Rio  2016     S          Justin GATLIN
# ...     ...                ...      ...   ...   ...                    ...
# 2326      W     Shot Put Women      Rio  2016     S          Valerie ADAMS
# 2327      W     Shot Put Women      Rio  2016     B           Anita MARTON
# 2366      W  Triple Jump Women      Rio  2016     G      Caterine IBARGUEN
# 2367      W  Triple Jump Women      Rio  2016     S          Yulimar ROJAS
# 2368      W  Triple Jump Women      Rio  2016     B          Olga RYPAKOVA
#
#      Nationality    Result
# 0            USA  25:05.17
# ...

# %%
results['Year'].mean()
# Out:
# 1970.189756507137

# %%
list(results['Year'])
# Out:
# [2016,
#  2016,
#  2016,
#  2008,
#  2008,
#  2008,
#  2000,
#  2000,
#  2000,
#  1992,
#  1992,
#  1992,
#  1984,
#  1984,
#  1984,
#  1976,
#  1976,
#  1976,
#  1968,
#  1968,
#  1968,
#  1960,
#  1960,
#  1960,
#  1952,
#  1952,
#  1952,
#  1936,
#  1936,
#  1936,
#  1928,
#  1928,
#  1928,
#  1920,
#  1920,
#  1920,
#  2012,
#  2012,
#  2012,
#  2004,
#  2004,
#  2004,
#  1996,
#  1996,
#  1996,
#  1980,
#  1980,
#  1980,
#  1972,
#  1972,
#  1972,
#  1964,
#  1964,
#  1964,
#  1956,
#  1956,
#  1956,
#  1948,
#  1948,
#  1948,
#  1932,
#  1932,
#  1932,
#  1924,
#  1924,
#  1924,
#  1912,
#  1912,
#  1912,
#  2016,
#  2016,
#  2016,
#  2008,
#  2008,
#  2008,
#  2000,
#  2000,
#  2000,
#  1992,
#  1992,
#  1992,
#  1984,
#  1984,
#  1984,
#  1976,
#  1976,
#  1976,
#  1968,
#  1968,
#  1968,
#  1960,
#  1960,
#  1960,
#  1952,
#  1952,
#  1952,
#  1936,
#  1936,
#  1936,
#  1928,
#  1928,
#  1928,
#  1920,
#  1920,
#  1920,
#  1908,
#  1908,
#  1908,
#  1900,
#  1900,
#  1900,
# ...

# %%
#Filtering by a list
results[results['Year'] >= 2004]
# Out:
#      Gender              Event Location  Year Medal                    Name  \
# 0         M         10000M Men      Rio  2016     G           Mohamed FARAH
# 1         M         10000M Men      Rio  2016     S   Paul Kipngetich TANUI
# 2         M         10000M Men      Rio  2016     B            Tamirat TOLA
# 3         M         10000M Men  Beijing  2008     G         Kenenisa BEKELE
# 4         M         10000M Men  Beijing  2008     S          Sileshi SIHINE
# ...     ...                ...      ...   ...   ...                     ...
# 2374      W  Triple Jump Women   London  2012     S       Caterine IBARGUEN
# 2375      W  Triple Jump Women   London  2012     B          Olga SALADUKHA
# 2376      W  Triple Jump Women   Athens  2004     G  Francoise MBANGO ETONE
# 2377      W  Triple Jump Women   Athens  2004     S       Hrysopiyi DEVETZI
# 2378      W  Triple Jump Women   Athens  2004     B        Tatyana LEBEDEVA
#
#      Nationality    Result
# 0            USA  25:05.17
# ...

# %%
len(results)
# Out:
# 2382

# %%
results
# Out:
#      Gender              Event Location  Year Medal                   Name  \
# 0         M         10000M Men      Rio  2016     G          Mohamed FARAH
# 1         M         10000M Men      Rio  2016     S  Paul Kipngetich TANUI
# 2         M         10000M Men      Rio  2016     B           Tamirat TOLA
# 3         M         10000M Men  Beijing  2008     G        Kenenisa BEKELE
# 4         M         10000M Men  Beijing  2008     S         Sileshi SIHINE
# ...     ...                ...      ...   ...   ...                    ...
# 2377      W  Triple Jump Women   Athens  2004     S      Hrysopiyi DEVETZI
# 2378      W  Triple Jump Women   Athens  2004     B       Tatyana LEBEDEVA
# 2379      W  Triple Jump Women  Atlanta  1996     G         Inessa KRAVETS
# 2380      W  Triple Jump Women  Atlanta  1996     S        Inna LASOVSKAYA
# 2381      W  Triple Jump Women  Atlanta  1996     B       Sarka KASPARKOVA
#
#      Nationality    Result
# 0            USA  25:05.17
# ...

# %%
results.iloc[2381]
# Out:
# Gender                         W
# Event          Triple Jump Women
# Location                 Atlanta
# Year                        1996
# Medal                          B
# Name            Sarka KASPARKOVA
# Nationality                  CZE
# Result                     14.98
# Name: 2381, dtype: object

# %%
primes = [2, 3, 5, 7, 11, 13, 17, 19]

# %%
prime_doubles = [x*2 for x in primes]
prime_doubles
# Out:
# [4, 6, 10, 14, 22, 26, 34, 38]

# %%
prime_doubles = [x*3 for x in primes]
prime_doubles
# Out:
# [6, 9, 15, 21, 33, 39, 51, 57]

# %%
indices, data =[2, 5, 7], [123, 345, 567]
zipped = zip(indices, data)
zipped

# %%
dict_comp = {x : y for x, y in zipped}
dict_comp
# Out:
# {2: 123, 5: 345, 7: 567}

# %%
#Working with Json
