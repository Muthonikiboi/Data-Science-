# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df_salary=pd.read_csv("Salary_dataset.csv")
df_salary
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
df_salary.columns
# Out:
# Index(['Unnamed: 0', 'YearsExperience', 'Salary'], dtype='object')

# %%
df_salary.index
# Out:
# RangeIndex(start=0, stop=30, step=1)

# %%
df_salary.head(10)
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0
# 5           5              3.0  56643.0
# 6           6              3.1  60151.0
# 7           7              3.3  54446.0
# 8           8              3.3  64446.0
# 9           9              3.8  57190.0

# %%
df_salary.tail(10)
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 20          20              6.9   91739.0
# 21          21              7.2   98274.0
# 22          22              8.0  101303.0
# 23          23              8.3  113813.0
# 24          24              8.8  109432.0
# 25          25              9.1  105583.0
# 26          26              9.6  116970.0
# 27          27              9.7  112636.0
# 28          28             10.4  122392.0
# 29          29             10.6  121873.0

# %%
df_salary.sample(5)
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 10          10              4.0   63219.0
# 24          24              8.8  109432.0
# 4            4              2.3   39892.0
# 27          27              9.7  112636.0
# 28          28             10.4  122392.0

# %%
df_salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
# Unnamed: 0         30 non-null int64
# YearsExperience    30 non-null float64
# Salary             30 non-null float64
# dtypes: float64(2), int64(1)
# memory usage: 800.0 bytes

# %%
df_salary.isna().sum()
# Out:
# Unnamed: 0         0
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
df_salary.dropna(inplace=True)
df_salary
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
df_salary.describe()
# Out:
#        Unnamed: 0  YearsExperience         Salary
# count   30.000000        30.000000      30.000000
# mean    14.500000         5.413333   76004.000000
# std      8.803408         2.837888   27414.429785
# min      0.000000         1.200000   37732.000000
# 25%      7.250000         3.300000   56721.750000
# 50%     14.500000         4.800000   65238.000000
# 75%     21.750000         7.800000  100545.750000
# max     29.000000        10.600000  122392.000000

# %%
df_salary.duplicated().sum()
# Out:
# 0

# %%
df_salary=df_salary[["Unnamed: 0","YearsExperience","Salary"]]
df_salary
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
df_salary.corr()
# Out:
#                  Unnamed: 0  YearsExperience    Salary
# Unnamed: 0         1.000000         0.986460  0.960826
# YearsExperience    0.986460         1.000000  0.978242
# Salary             0.960826         0.978242  1.000000

# %%
corr = df_salary.corr(method="spearman")
sns.heatmap(corr,annot=True)
plt.show()

# %%
sns.pairplot(df_salary)

# %%
new_salary=df_salary.drop("Unnamed: 0", axis=1)   # drop ana end column
new_salary
# Out:
#     YearsExperience    Salary
# 0               1.2   39344.0
# 1               1.4   46206.0
# 2               1.6   37732.0
# 3               2.1   43526.0
# 4               2.3   39892.0
# 5               3.0   56643.0
# 6               3.1   60151.0
# 7               3.3   54446.0
# 8               3.3   64446.0
# 9               3.8   57190.0
# 10              4.0   63219.0
# 11              4.1   55795.0
# 12              4.1   56958.0
# 13              4.2   57082.0
# 14              4.6   61112.0
# 15              5.0   67939.0
# 16              5.2   66030.0
# 17              5.4   83089.0
# 18              6.0   81364.0
# 19              6.1   93941.0
# 20              6.9   91739.0
# 21              7.2   98274.0
# 22              8.0  101303.0
# 23              8.3  113813.0
# 24              8.8  109432.0
# 25              9.1  105583.0
# 26              9.6  116970.0
# 27              9.7  112636.0
# 28             10.4  122392.0
# 29             10.6  121873.0

# %%
# draw scatter plot-seperate from the other graphs so a it appears singly
sns.scatterplot( x="YearsExperience" , y="Salary" ,data=new_salary )

# %%
#plot a distribution plot
sns.distplot(new_salary["Salary"])
# Out:
# /home/zaki-dev/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.boxplot(new_salary["Salary"])

# %%
sns.boxplot(new_salary["YearsExperience"])

# %%
sns.heatmap(new_salary.corr(), annot=True)

# %%
sns.displot( new_salary["Salary"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-a25dc13c0c36> in <module>()
# ----> 1 sns.displot( new_salary["Salary"])
#
# AttributeError: module 'seaborn' has no attribute 'displot'

# %%
x=np.array(new_salary["YearsExperience"])
y=np.array(new_salary["Salary"])

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size = 0.2)

print("Split done")
# Out:
# Split done

# %%
sns.__version__
# Out:
# '0.9.0'

# %%
# !pip install seaborn==0.12.2
# Out:
# ...
#     100% |████████████████████████████████| 296kB 821kB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 9.5MB 160kB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 11.2MB 205kB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 10.3MB 117kB/s ta 0:00:01   16% |█████▏                          | 1.6MB 383kB/s eta 0:00:23    58% |██████████████████▉             | 6.0MB 175kB/s eta 0:00:25
#   Installing build dependencies ... done
# ...
#     100% |████████████████████████████████| 972kB 390kB/s ta 0:00:01    57% |██████████████████▎             | 552kB 91kB/s eta 0:00:05
# ...
#     100% |████████████████████████████████| 50.5MB 128kB/s ta 0:00:012
# ...
#   Using cached https://files.pythonhosted.org/packages/a4/24/6ae4c9c45cf99d96b06b5d99e25526c060303171fb0aea9da2bfd7dbde93/pyparsing-3.1.0-py3-none-any.whl
# ...
#     100% |████████████████████████████████| 51kB 730kB/s ta 0:00:01
# ...
#   Running setup.py bdist_wheel for numpy ... done
# ...

# %%
sns.displot( new_salary["Salary"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-a25dc13c0c36> in <module>()
# ----> 1 sns.displot( new_salary["Salary"])
#
# AttributeError: module 'seaborn' has no attribute 'displot'
